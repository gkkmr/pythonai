# %% [markdown]
# <h1>Forecasting number of Air Passengers for next 10 years</h1>

# %% [markdown]
# - Importing all the required libraries for analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - Reading the dataset file and checking the size of file

# %%
#data=pd.read_csv(r'C:\Users\manis\Desktop\IBM_Data_science\Air_Passenger\AirPassengers.csv')

path='C:\\Users\\arunk\\Downloads\\Intelli\\IntelliDataSciencePython\\PythonDataScience\\1PythonTrainingToUSe\\DoIt\\DoIt2\\17Mod_TimeSeries\\Air-Passengers-Time-Series-Analysis-master\\Data\\AirPassengers.csv'
data=pd.read_csv(path)
data.shape
# Out:
# (144, 2)

# %%
pd.set_option("display.max_rows", None)

# %%
#data.head(20)
data
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# 5    1949-06         135
# 6    1949-07         148
# 7    1949-08         148
# 8    1949-09         136
# 9    1949-10         119
# 10   1949-11         104
# 11   1949-12         118
# 12   1950-01         115
# 13   1950-02         126
# 14   1950-03         141
# 15   1950-04         135
# 16   1950-05         125
# 17   1950-06         149
# 18   1950-07         170
# 19   1950-08         170
# 20   1950-09         158
# 21   1950-10         133
# 22   1950-11         114
# 23   1950-12         140
# 24   1951-01         145
# 25   1951-02         150
# 26   1951-03         178
# 27   1951-04         163
# 28   1951-05         172
# 29   1951-06         178
# 30   1951-07         199
# 31   1951-08         199
# 32   1951-09         184
# 33   1951-10         162
# 34   1951-11         146
# 35   1951-12         166
# 36   1952-01         171
# 37   1952-02         180
# 38   1952-03         193
# 39   1952-04         181
# 40   1952-05         183
# 41   1952-06         218
# 42   1952-07         230
# 43   1952-08         242
# 44   1952-09         209
# 45   1952-10         191
# 46   1952-11         172
# 47   1952-12         194
# 48   1953-01         196
# 49   1953-02         196
# 50   1953-03         236
# 51   1953-04         235
# 52   1953-05         229
# 53   1953-06         243
# 54   1953-07         264
# 55   1953-08         272
# 56   1953-09         237
# 57   1953-10         211
# 58   1953-11         180
# 59   1953-12         201
# 60   1954-01         204
# 61   1954-02         188
# 62   1954-03         235
# 63   1954-04         227
# 64   1954-05         234
# 65   1954-06         264
# 66   1954-07         302
# 67   1954-08         293
# 68   1954-09         259
# 69   1954-10         229
# 70   1954-11         203
# 71   1954-12         229
# 72   1955-01         242
# 73   1955-02         233
# 74   1955-03         267
# 75   1955-04         269
# 76   1955-05         270
# 77   1955-06         315
# 78   1955-07         364
# 79   1955-08         347
# 80   1955-09         312
# 81   1955-10         274
# 82   1955-11         237
# 83   1955-12         278
# 84   1956-01         284
# 85   1956-02         277
# 86   1956-03         317
# 87   1956-04         313
# 88   1956-05         318
# 89   1956-06         374
# 90   1956-07         413
# 91   1956-08         405
# 92   1956-09         355
# 93   1956-10         306
# 94   1956-11         271
# 95   1956-12         306
# 96   1957-01         315
# 97   1957-02         301
# 98   1957-03         356
# 99   1957-04         348
# 100  1957-05         355
# 101  1957-06         422
# 102  1957-07         465
# 103  1957-08         467
# 104  1957-09         404
# 105  1957-10         347
# 106  1957-11         305
# 107  1957-12         336
# 108  1958-01         340
# 109  1958-02         318
# 110  1958-03         362
# 111  1958-04         348
# 112  1958-05         363
# 113  1958-06         435
# 114  1958-07         491
# 115  1958-08         505
# 116  1958-09         404
# 117  1958-10         359
# 118  1958-11         310
# 119  1958-12         337
# 120  1959-01         360
# 121  1959-02         342
# 122  1959-03         406
# 123  1959-04         396
# 124  1959-05         420
# 125  1959-06         472
# 126  1959-07         548
# 127  1959-08         559
# 128  1959-09         463
# 129  1959-10         407
# 130  1959-11         362
# 131  1959-12         405
# 132  1960-01         417
# 133  1960-02         391
# 134  1960-03         419
# 135  1960-04         461
# 136  1960-05         472
# 137  1960-06         535
# 138  1960-07         622
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %% [markdown]
# - Creating the 'Date' as Index for data and viewing the dataset

# %%
print(data.info())
print(data.describe())
print(data.describe(include='object'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB
# None
#        Passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000
#           Month
# count       144
# unique      144
# top     1951-02
# freq          1

# %%
data['Month']=pd.to_datetime(data['Month'], infer_datetime_format=True)
data=data.set_index(['Month'])
print(data.head())
print(data.tail())
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
#             Passengers
# Month
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %% [markdown]
# # Exploring the dataset

# %% [markdown]
# # Check the Stationarity of data ?  (Method 1) Visual-Mean+Std charts (Method 2) ADF Augmented Dickey Fuller

# %% [markdown]
# # Check the Stationarity of data ? (Method 1) Visual-Mean+Std charts

# %%
#plt.figure(figsize=(20,10))
plt.xlabel("Month")
plt.ylabel("Number of Air Passengers")
plt.plot(data)
plt.show()

# %% [markdown]
# # Check Data Stationarity ? using Rolling - Mean and Std

# %%
#rolmean=data.rolling(window=12).mean()
#rolling window means how many rows it is considering calculating the mean.
#rolmean=data.rolling(window=2).mean(), 2 means 2 rows. 12 means 12 rows

print(pd.options.display.max_rows)
rolmean=data.rolling(window=12).mean()
rolstd=data.rolling(window=12).std()
#display all the rows
pd.options.display.max_rows
print(rolmean,rolstd)
# Out:
# None
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1955-09-01   50.842597
# 1955-10-01   48.897775
# 1955-11-01   45.048375
# 1955-12-01   42.140458
# 1956-01-01   40.026128
# 1956-02-01   36.433834
# 1956-03-01   36.277550
# 1956-04-01   35.591112
# 1956-05-01   34.722275
# 1956-06-01   40.304429
# 1956-07-01   48.209769
# 1956-08-01   54.530781
# 1956-09-01   55.586883
# 1956-10-01   53.899668
# 1956-11-01   49.692616
# 1956-12-01   47.861780
# 1957-01-01   46.058921
# 1957-02-01   43.983123
# 1957-03-01   44.147394
# 1957-04-01   43.636932
# 1957-05-01   43.324271
# 1957-06-01   48.451397
# 1957-07-01   56.617470
# 1957-08-01   64.351956
# 1957-09-01   65.848771
# 1957-10-01   63.844211
# 1957-11-01   60.026446
# 1957-12-01   57.890898
# 1958-01-01   56.219537
# 1958-02-01   54.496803
# 1958-03-01   54.364859
# 1958-04-01   54.364859
# 1958-05-01   54.180604
# 1958-06-01   55.364632
# 1958-07-01   59.590013
# 1958-08-01   65.557054
# 1958-09-01   65.557054
# 1958-10-01   65.106207
# 1958-11-01   64.593074
# 1958-12-01   64.530472
# 1959-01-01   63.627229
# 1959-02-01   61.759553
# 1959-03-01   61.597422
# 1959-04-01   60.284678
# 1959-05-01   60.008270
# 1959-06-01   63.009138
# 1959-07-01   71.987951
# 1959-08-01   80.049369
# 1959-09-01   81.485451
# 1959-10-01   79.680422
# 1959-11-01   74.498729
# 1959-12-01   69.830097
# 1960-01-01   66.624399
# 1960-02-01   61.866180
# 1960-03-01   61.382741
# 1960-04-01   60.171472
# 1960-05-01   60.184565
# 1960-06-01   65.021849
# 1960-07-01   77.194510
# 1960-08-01   83.630500
# 1960-09-01   84.617276
# 1960-10-01   82.541954
# 1960-11-01   79.502382
# 1960-12-01   77.737125

# %%
#print(rolmean.head(15)) 
# has NA in the first 12 rows and it contains the means of the first 12 rows in #print(data.head(15))

# %%
print(data.head(15))
print(rolmean.head(15))
print(rolstd.head(15))
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# 1949-06-01         135
# 1949-07-01         148
# 1949-08-01         148
# 1949-09-01         136
# 1949-10-01         119
# 1949-11-01         104
# 1949-12-01         118
# 1950-01-01         115
# 1950-02-01         126
# 1950-03-01         141
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01  126.666667
# 1950-01-01  126.916667
# 1950-02-01  127.583333
# 1950-03-01  128.333333
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01   13.720147
# 1950-01-01   13.453342
# 1950-02-01   13.166475
# 1950-03-01   13.686977

# %% [markdown]
# # Check Data Stationarity ? Visual Data of using Rolling - Mean and Std

# %%
#plt.figure(figsize=(20,10))
plt.xlabel("Month")
plt.ylabel("Number of Air Passengers")

org=plt.plot(data,color='blue',label='orginal data')
mean=plt.plot(rolmean,color='red',label='mean data')
std=plt.plot(rolstd,color='green',label='std data')
plt.legend(loc='best')
plt.title('Orginal,Rolling Mean, Rolling Std')
plt.show()

# %% [markdown]
# # Another method to  Check  Stationarity ? using Augmented Dickey-Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller
print('Dickey-Fuller Test: ')
dftest=adfuller(data['Passengers'], autolag='AIC')
dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Dickey-Fuller Test:
# Test Statistic            0.815369
# p-value                   0.991880
# Lags Used                13.000000
# No. of Obs              130.000000
# Critical Value (1%)      -3.481682
# Critical Value (5%)      -2.884042
# Critical Value (10%)     -2.578770
# dtype: float64

# %% [markdown]
# # Create a function test_stationarity - to visually test and to use Augumented Dickey Fuller test

# %%
def test_stationarity(timeseries):
    
    #plot rolling statistics
    
    org=plt.plot(timeseries,color='blue',label='orginal data')
    mean=plt.plot(timeseries.rolling(window=12).mean(),color='red',label='mean data')
    std=plt.plot(timeseries.rolling(window=12).std(),color='green',label='std data')
    
    plt.legend(loc='best')
    plt.title('Orginal,Rolling Mean, Rolling Std')
    
    plt.xlabel("Month")
    plt.ylabel("Number of Air Passengers")
    
    plt.show()
    
    #plot rolling statistics
    from statsmodels.tsa.stattools import adfuller

    print('Dickey-Fuller Test: ')
    dftest=adfuller(timeseries['Passengers'], autolag='AIC')
    dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(data)
# Out:
# Dickey-Fuller Test:
# Test Statistic            0.815369
# p-value                   0.991880
# Lags Used                13.000000
# No. of Obs              130.000000
# Critical Value (1%)      -3.481682
# Critical Value (5%)      -2.884042
# Critical Value (10%)     -2.578770
# dtype: float64

# %% [markdown]
# # Converting Non Stationary Dataset to Stationary

# %% [markdown]
# 1)Log<br>
# 2)Differencing Simple Moving Average(Substracting Simple Rolling Averages)<br>
# 3)Differencing Exponential Moving Averages(Substracting Exponential Rolling Averages)<br>
# 4)Substracting Previous Value (Most Popular) with Shift. Subtracting each value from its previous value.<br>
# 5)Seasonal Decomposition. <br>

# %% [markdown]
# # Method 1-log- transformation to make our Time series stationary

# %% [markdown]
# - Below we took log transformation to make our Time series stationary and plotted visual for it
# - We found graph upward trending over time with seasonality

# %%
#plt.figure(figsize=(20,10))
data_log=np.log(data)
plt.plot(data_log)
plt.show()

# %% [markdown]
# # # Check Stationarity Visually ? by Testing with Rolling - Mean and Std on log data

# %%
test_stationarity(data_log)
# Out:
# Dickey-Fuller Test:
# Test Statistic           -1.717017
# p-value                   0.422367
# Lags Used                13.000000
# No. of Obs              130.000000
# Critical Value (1%)      -3.481682
# Critical Value (5%)      -2.884042
# Critical Value (10%)     -2.578770
# dtype: float64

# %% [markdown]
# # Method 2)Differencing Simple Moving Average(Substracting Simple Rolling Averages)

# %%
MAvg=data_log.rolling(window=12).mean()

print(MAvg.head(12))
# Out:
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01    4.836178

# %%
data_log_subtract_MAvg=data_log-MAvg
print(data_log_subtract_MAvg.head(12))
# Out:
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01   -0.065494

# %%
data_log_subtract_MAvg.dropna(inplace=True)
print(data_log_subtract_MAvg.head(12))
# Out:
#             Passengers
# Month
# 1949-12-01   -0.065494
# 1950-01-01   -0.093449
# 1950-02-01   -0.007566
# 1950-03-01    0.099416
# 1950-04-01    0.052142
# 1950-05-01   -0.027529
# 1950-06-01    0.139881
# 1950-07-01    0.260184
# 1950-08-01    0.248635
# 1950-09-01    0.162937
# 1950-10-01   -0.018578
# 1950-11-01   -0.180379

# %% [markdown]
# See the chart below. Here the read and green is not changing much. It is almost like a straight line. Also the P-value is 0.022235 and it is less than .05. That means the data is now stationary.Which means Simple MVA is giving us stationarity Dataset

# %%
test_stationarity(data_log_subtract_MAvg)
# Out:
# Dickey-Fuller Test:
# Test Statistic           -3.162908
# p-value                   0.022235
# Lags Used                13.000000
# No. of Obs              119.000000
# Critical Value (1%)      -3.486535
# Critical Value (5%)      -2.886151
# Critical Value (10%)     -2.579896
# dtype: float64

# %% [markdown]
# # Method 3)Differencing Exponential Moving Averages(Substracting Exponential Rolling Averages)<br>

# %%
exponentialMVA=data_log.ewm (halflife=12,min_periods=0,adjust=True).mean()

# %%
data_log_subtract_exponentialMVA=data_log-exponentialMVA
data_log_subtract_exponentialMVA.dropna(inplace=True)

# %%
test_stationarity(data_log_subtract_exponentialMVA)
# Out:
# Dickey-Fuller Test:
# Test Statistic           -3.601262
# p-value                   0.005737
# Lags Used                13.000000
# No. of Obs              130.000000
# Critical Value (1%)      -3.481682
# Critical Value (5%)      -2.884042
# Critical Value (10%)     -2.578770
# dtype: float64

# %% [markdown]
# # 4)Substracting Previous Value (Most Popular) with Shift. Subtracting each value from its previous value.

# %%
logShift=data_log.shift()

# %%
logShift.head(10)
# Out:
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01    4.718499
# 1949-03-01    4.770685
# 1949-04-01    4.882802
# 1949-05-01    4.859812
# 1949-06-01    4.795791
# 1949-07-01    4.905275
# 1949-08-01    4.997212
# 1949-09-01    4.997212
# 1949-10-01    4.912655

# %%
data_shift=data_log-logShift

# %%
print(data_shift.head())
print(data_log.head())
# Out:
#             Passengers
# Month
# 1949-01-01         NaN
# 1949-02-01    0.052186
# 1949-03-01    0.112117
# 1949-04-01   -0.022990
# 1949-05-01   -0.064022
#             Passengers
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791

# %% [markdown]
# See the chart below. Here The p-value 0.071121 and it is MORE than .05. That means the data is now NOT stationary.
# Which means SHIFT is giving NOT giving us stationarity Dataset

# %%
data_shift.dropna(inplace=True)
test_stationarity(data_shift)
# Out:
# Dickey-Fuller Test:
# Test Statistic           -2.717131
# p-value                   0.071121
# Lags Used                14.000000
# No. of Obs              128.000000
# Critical Value (1%)      -3.482501
# Critical Value (5%)      -2.884398
# Critical Value (10%)     -2.578960
# dtype: float64

# %% [markdown]
# # Method 5)Seasonal Decomposition.

# %% [markdown]
# - Decomposing Time Series into its components : Trend, Seasonality and Residual

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp=seasonal_decompose(data_log)

trend=decomp.trend
seasonal=decomp.seasonal
residual=decomp.resid

plt.subplot(411)
plt.plot(data_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')


plt.legend(loc='best')
plt.tight_layout()
#****

# %%
print(residual)

# %% [markdown]
# - Checking the stationarity of Time Series components

# %% [markdown]
# # Now let us find the lags using ACF, PACF

# %%
from statsmodels.tsa.stattools import acf, pacf

lag_acf=acf(data_shift, nlags=20)
lag_pacf=pacf(data_shift, nlags=20, method='ols')

#plt.figure(figsize=(20,10))
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.axhline(y=1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.title('Autocorrelation Function')

plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.axhline(y=1.96/np.sqrt(len(data_shift)),linestyle='--',color='green')
plt.title('Partial Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation Function')

# %% [markdown]
# - Building the ARIMA model with p=2, q=2 and I=1

# %% [markdown]
# # Using arma_order_select_ic to get the value of P and Q

# %% [markdown]
# Here the values of 'bic_min_order': (2, 2)}, here the value of P=2 and Q=2

# %%
from statsmodels.tsa.stattools import arma_order_select_ic

# %%
#arma_order_select_ic(data_shift)
arma_order_select_ic(data_log_subtract_exponentialMVA)
# Out:
# {'bic':             0           1           2
#  0 -158.511120 -257.250251 -263.047178
#  1 -255.493902 -270.895496 -265.966226
#  2 -275.393275 -274.626092 -270.395051
#  3 -272.045119 -270.101151 -271.959222
#  4 -271.811015 -266.284288 -267.736363,
#  'bic_min_order': (2, 0)}

# %% [markdown]
# # AR Model

# %% [markdown]
# here we are plotting the AR model becuase we have passed a values of 2,1,0. the zero indicates MA=0. model=ARIMA(data_log, order=(2,1,2))

# %%
from statsmodels.tsa.arima_model import ARIMA
print('Plotting AR Model')
#plt.figure(figsize=(20,10))
# order=(p=2,i=1,q=2)
model=ARIMA(data_log, order=(2,1,0))
results=model.fit(disp=-1)
plt.plot(data_shift)
plt.plot(results.fittedvalues, color='red')
#the title is giving us the difference in errors. the lower the RSS , the better it is
plt.title('RMSE: %.4f'% sum((results.fittedvalues-data_shift['Passengers'])**2))
print('plotting AR model END')
print('*******')
# Out:
# Plotting AR Model
# plotting AR model END
# *******
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# # MA Model

# %%
from statsmodels.tsa.arima_model import ARIMA
print('Plotting MA Model')
#plt.figure(figsize=(20,10))
model=ARIMA(data_log, order=(0,1,2))
results=model.fit(disp=-1)
plt.plot(data_shift)
plt.plot(results.fittedvalues, color='red')
plt.title('RMSE: %.4f'% sum((results.fittedvalues-data_shift['Passengers'])**2))
print('plotting MA model END')
print('*******')
# Out:
# Plotting MA Model
# plotting MA model END
# *******
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# # Model with ARIMA

# %%
from statsmodels.tsa.arima_model import ARIMA

plt.figure(figsize=(20,10))
model=ARIMA(data_log, order=(2,1,2))
results=model.fit(disp=-1)
plt.plot(data_shift)
plt.plot(results.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results.fittedvalues-data_shift['Passengers'])**2))
print('plotting ARIMA model')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# plotting ARIMA model

# %% [markdown]
# # Get the Predicted values

# %%
predictions=pd.Series(results.fittedvalues, copy=True)
print(predictions.head())
# Out:
# Month
# 1949-02-01    0.009580
# 1949-03-01    0.017491
# 1949-04-01    0.027670
# 1949-05-01   -0.004521
# 1949-06-01   -0.023890
# dtype: float64

# %% [markdown]
# - To remove the differencing we need to do a cumulative SUM
# - Performing Inverse Transformation for differencing, by doing cumulative sum

# %%
predictions_cum_sum=predictions.cumsum()
#print(predictions_cum_sum.head())
print(predictions_cum_sum)
# Out:
# Month
# 1949-02-01    0.009580
# 1949-03-01    0.027071
# 1949-04-01    0.054742
# 1949-05-01    0.050221
# 1949-06-01    0.026331
# 1949-07-01    0.021984
# 1949-08-01    0.011007
# 1949-09-01   -0.018922
# 1949-10-01   -0.053389
# 1949-11-01   -0.064668
# 1949-12-01   -0.027456
# 1950-01-01    0.040679
# 1950-02-01    0.130113
# 1950-03-01    0.220142
# 1950-04-01    0.286294
# 1950-05-01    0.330348
# 1950-06-01    0.365815
# 1950-07-01    0.368915
# 1950-08-01    0.321787
# 1959-10-01    0.945772
# 1959-11-01    0.876507
# 1959-12-01    0.872864
# 1960-01-01    0.907083
# 1960-02-01    0.973094
# 1960-03-01    1.078207
# 1960-04-01    1.196164
# 1960-05-01    1.300218
# 1960-06-01    1.382013
# 1960-07-01    1.413731
# 1960-08-01    1.372555
# 1960-09-01    1.280205
# 1960-10-01    1.186192
# 1960-11-01    1.116268
# 1960-12-01    1.108141
# dtype: float64

# %% [markdown]
# - Below is data display of predicted value in log scale

# %%
data_log.head(10)
# Out:
#             Passengers
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
# 1949-06-01    4.905275
# 1949-07-01    4.997212
# 1949-08-01    4.997212
# 1949-09-01    4.912655
# 1949-10-01    4.779123

# %%
data_log['Passengers'].iloc[0]
# Out:
# 4.718498871295094

# %%
#predictions_log=pd.Series(data_log['Passengers'].ix[0], index=data_log.index)

predictions_log=pd.Series(data_log['Passengers'].iloc[0], index=data_log.index)
predictions_log=predictions_log.add(predictions_cum_sum,fill_value=0)
predictions_log.head()
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.728079
# 1949-03-01    4.745570
# 1949-04-01    4.773241
# 1949-05-01    4.768720
# dtype: float64

# %% [markdown]
# Here we need to convert the log to the orginal form. To convert the log to the orginal form we going take the EXPONENTIAL VALUE of the data

# %%
predictions_ARIMA=np.exp(predictions_log)

# %%
predictions_ARIMA.head()
# Out:
# Month
# 1949-01-01    112.000000
# 1949-02-01    113.078123
# 1949-03-01    115.073415
# 1949-04-01    118.301989
# 1949-05-01    117.768367
# dtype: float64

# %%
data.head(4)
data.shape
# Out:
# (144, 1)

# %% [markdown]
# Taking out log transformation and visualizing actual vs predicted value graph

# %%
#plt.figure(figsize=(20,10))
plt.plot(data)
plt.plot(predictions_ARIMA)
plt.show()

# %% [markdown]
# - Plotting the visual for forecast of next 10 years with 95% confidence interval

# %%
#rcParams['figure.figsize']=20,10

results.plot_predict(1,204)
x=results.forecast(steps=120)

# %% [markdown]
# - Next 10 years predicted value on log scale

# %%
x[0]
# Out:
# array([6.09553384, 6.15281391, 6.22442954, 6.29241094, 6.34164717,
#        6.3635937 , 6.35784701, 6.33139322, 6.29597558, 6.26447727,
#        6.24738333, 6.25025173, 6.27275833, 6.30940308, 6.3515149 ,
#        6.38988657, 6.41727388, 6.43011066, 6.42906704, 6.41842505,
#        6.4045617 , 6.39403627, 6.3918309 , 6.40019507, 6.41833695,
#        6.4429541 , 6.4693744 , 6.49293994, 6.51024131, 6.51989048,
#        6.52267594, 6.52112403, 6.51864541, 6.51853701, 6.52311932,
#        6.53322369, 6.54812878, 6.56591566, 6.5841032 , 6.60036553,
#        6.61313281, 6.62192797, 6.62737805, 6.63093145, 6.63438704,
#        6.63937999, 6.64696518, 6.65739854, 6.67015338, 6.68414265,
#        6.69806642, 6.71077918, 6.7215775 , 6.73034002, 6.73749829,
#        6.74386397, 6.75037341, 6.7578261 , 6.76668699, 6.7769984 ,
#        6.78841337, 6.80032872, 6.81207214, 6.8230878 , 6.83307157,
#        6.84202513, 6.85022333, 6.85811242, 6.86617361, 6.87479172,
#        6.88416323, 6.89426405, 6.90487911, 6.9156796 , 6.92632219,
#        6.93654163, 6.94621291, 6.95536961, 6.96417832, 6.97288037,
#        6.98171994, 6.99087899, 7.00043553, 7.01035388, 7.02050616,
#        7.03071588, 7.04080993, 7.05066415, 7.06023108, 7.06954451,
#        7.07870189, 7.08783182, 7.09705661, 7.10646052, 7.11607139,
#        7.12585923, 7.13575025, 7.14565107, 7.15547557, 7.16516693,
#        7.17470967, 7.18412935, 7.19348151, 7.20283372, 7.21224642,
#        7.22175765, 7.23137526, 7.24107809, 7.25082457, 7.26056595,
#        7.27025997, 7.27988139, 7.28942689, 7.29891364, 7.30837259,
#        7.3178388 , 7.32734172, 7.33689794, 7.34650815, 7.35615868])

# %% [markdown]
# - Actual predicted value for next 10 years, after taking out log transformation

# %%
np.exp(x[0])
# Out:
# array([ 443.8709397 ,  470.03817154,  504.93491563,  540.45476517,
#         567.73069016,  580.32814052,  577.00273532,  561.93895548,
#         542.3847266 ,  525.56678624,  516.65912943,  518.1432408 ,
#         529.93710564,  549.71671122,  573.36063761,  595.78899358,
#         612.33154739,  620.24257939,  619.59562325,  613.03685094,
#         604.59674286,  598.26647697,  596.94853277,  601.96245271,
#         612.98284222,  628.26000584,  645.08004071,  660.46223162,
#         671.98855268,  678.50406969,  680.39665447,  679.34155433,
#         677.65981052,  677.58636036,  680.69839573,  687.61128658,
#         697.93695567,  710.46214363,  723.50191693,  735.36393611,
#         744.81272636,  751.39236544,  755.49869399,  758.1880559 ,
#         760.81257694,  764.6207734 ,  770.44261823,  778.52300238,
#         788.51653871,  799.62482909,  810.83649025,  821.21025961,
#         830.12600187,  837.43196292,  843.44803379,  848.83427544,
#         854.37773299,  860.76893397,  868.4300065 ,  877.43107424,
#         887.50430193,  898.14248089,  908.75191596,  918.81775893,
#         928.03696634,  936.38351746,  944.09172911,  951.56920764,
#         959.27098846,  967.57381565,  976.68407158,  986.5993687 ,
#         997.12796157, 1007.95580317, 1018.74034842, 1029.20468273,
#        1039.20669281, 1048.76610422, 1058.04519017, 1067.29252714,
#        1076.76875635, 1086.67623585, 1097.11087759, 1108.04655602,
#        1119.35304433, 1130.83986109, 1142.312423  , 1153.62466429,
#        1164.71427975, 1175.61242959, 1186.42740509, 1197.30900315,
#        1208.40503212, 1219.82236144, 1231.60243399, 1243.71634575,
#        1256.07900815, 1268.57699409, 1281.10154472, 1293.57752115,
#        1305.98087952, 1318.34093109, 1330.72809245, 1343.23171548,
#        1355.93485155, 1368.89297721, 1382.12197864, 1395.59774032,
#        1409.26641205, 1423.06169809, 1436.92396779, 1450.81593429,
#        1464.73099883, 1478.69265558, 1492.74589915, 1506.94364854,
#        1521.33226798, 1535.9401318 , 1550.77200543, 1565.81021729])

# %% [markdown]
# <b>*************************End****************************</b>
